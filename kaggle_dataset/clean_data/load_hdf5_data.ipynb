# %%
import numpy as np
import pandas as pd

# %%
# Generate Path to dataset

## fill in the path to the local directory, if the dataset is not saved in the same folder as the notebook
local_file_dir = ""
path_to_dataset = local_file_dir+"nips_dataset_cleared.h5"

# %%
# Load individual data frames

authors = pd.read_hdf(path_to_dataset, 'authors')
papers = pd.read_hdf(path_to_dataset, 'papers')
institution = pd.read_hdf(path_to_dataset, 'institutions')

# %%
authors
# Out:
#        paper_index                   name  \
# 1            12020       Sangnie Bhardwaj
# 2            12020            Ian Fischer
# 3            12020         Johannes Ballé
# 4            12020            Troy Chinen
# 5            22020  Jean-Baptiste Alayrac
# ...            ...                    ...
# 36823     86932019            Joshua Wang
# 36824     23022019             Ruho Kondo
# 36825     23022019         Keisuke Kawano
# 36826     23022019          Satoshi Koide
# 36827     23022019         Takuro Kutsuna
#
#                                  institution
# 1                                     google
# 2                                     google
# 3                                     google
# 4                                     google
# 5      massachusetts institute of technology
# ...                                      ...
# 36823                                 google
# 36824         toyota central r&d labs., inc.
# ...

# %%
papers
# Out:
#                                                    title  \
# 1      An Unsupervised Information-Theoretic Perceptu...
# 2          Self-Supervised MultiModal Versatile Networks
# 3      Benchmarking Deep Inverse Models over time, an...
# 4      Off-Policy Evaluation and Learning for Externa...
# 5      Neural Methods for Point-wise Dependency Estim...
# ...                                                  ...
# 11275  Discrete Object Generation with Reversible Ind...
# 11276  Adaptively Aligned Image Captioning via Adapti...
# 11277         Fully Dynamic Consistent Facility Location
# 11278      Efficient Rematerialization for Deep Networks
# 11279  Flow-based Image-to-Image Translation with Fea...
#
#                                                 abstract  year  paper_index
# 1      Tractable models of human perception have prov...  2020        12020
# 2      Videos are a rich source of multi-modal superv...  2020        22020
# ...

# %%
institution
# Out:
#     Unnamed: 0                       institutions               city state  \
# 0            0                stanford university           Stanford    CA
# 1            1                                mit          Cambridge    MA
# 2            2         carnegie mellon university         Pittsburgh    PA
# 3            3                        uc berkeley           Berkeley    CA
# 4            4                             google      Mountain View    CA
# ..         ...                                ...                ...   ...
# 95          95  the university of texas at austin             Austin    TX
# 96          96             university of virginia    Charlottesville    VA
# 97          97                           facebook         Menlo Park    CA
# 98          98                 rutgers university  Newark and Camden    NJ
# 99          99                      virginia tech         Blacksburg    VA
#
#    country
# 0       US
# 1       US
# 2       US
# 3       US
# ...

# %%
# for Ding-Ze only names to scrape author's ID from semantic scholar
pd.DataFrame(authors['name'].unique()).to_csv("authors_list_for_semantic_scholar_id.csv", index=False, header=False)
