# %%
import numpy as np
import pandas as pd
import csv
import json

# %% [markdown]
# # Load Data
#
# ## Author loading

# %%
authors = pd.read_csv("./kaggle_archive/authors.csv")

# check how many entries are deleted trough dropping missing data
print(f"deleted entries through missing data {authors.shape[0]-authors.dropna().shape[0]}")

# drop missing data
authors = authors.dropna()
# Out:
# deleted entries through missing data 1185

# %%
authors
# Out:
#        paper_index                   name  \
# 1            12020       Sangnie Bhardwaj
# 2            12020            Ian Fischer
# 3            12020         Johannes Ballé
# 4            12020            Troy Chinen
# 5            22020  Jean-Baptiste Alayrac
# ...            ...                    ...
# 36823     86932019            Joshua Wang
# 36824     23022019             Ruho Kondo
# 36825     23022019         Keisuke Kawano
# 36826     23022019          Satoshi Koide
# 36827     23022019         Takuro Kutsuna
#
#                                  institution  is_chinese  \
# 1                                     google           0
# 2                                     google           0
# 3                                     google           0
# 4                                     google           0
# 5      massachusetts institute of technology           0
# ...                                      ...         ...
# 36823                                 google           1
# 36824         toyota central r&d labs., inc.           0
# 36825          toyota central r&d labs., inc           0
# 36826               toyota central r&d labs.           0
# 36827          toyota central r&d labs. inc.           0
#
#             name_in_database
# 1           Sangnie Bhardwaj
# 2                Ian Fischer
# 3             Johannes Ballé
# 4                Troy Chinen
# 5      Jean-Baptiste Alayrac
# ...                      ...
# 36823            Joshua Wang
# 36824             Ruho Kondo
# 36825         Keisuke Kawano
# 36826          Satoshi Koide
# 36827         Takuro Kutsuna
#
# [35643 rows x 5 columns]

# %% [markdown]
# ## Paper loading

# %%
paper = pd.read_csv("./kaggle_archive/papers.csv")

# check how many entries are deleted trough dropping missing data
print(f"deleted entries through missing data {paper.shape[0]-paper.dropna().shape[0]}")

# drop missing data
paper = paper.dropna()
# Out:
# deleted entries through missing data 3342

# %%
paper
# Out:
#        Unnamed: 0                                              title  \
# 0               0               A graph similarity for deep learning
# 1               1  An Unsupervised Information-Theoretic Perceptu...
# 2               2      Self-Supervised MultiModal Versatile Networks
# 3               3  Benchmarking Deep Inverse Models over time, an...
# 4               4  Off-Policy Evaluation and Learning for Externa...
# ...           ...                                                ...
# 11275       11275  Discrete Object Generation with Reversible Ind...
# 11276       11276  Adaptively Aligned Image Captioning via Adapti...
# 11277       11277         Fully Dynamic Consistent Facility Location
# 11278       11278      Efficient Rematerialization for Deep Networks
# 11279       11279  Flow-based Image-to-Image Translation with Fea...
#
#                                                 abstract  year  paper_index  \
# 0      Graph neural networks (GNNs) have been success...  2020         2020
# 1      Tractable models of human perception have prov...  2020        12020
# 2      Videos are a rich source of multi-modal superv...  2020        22020
# 3      We consider the task of solving generic invers...  2020        32020
# 4      We consider the evaluation and training of a n...  2020        42020
# ...                                                  ...   ...          ...
# 11275  The success of generative modeling in continuo...  2019     54522019
# 11276  Recent neural models for image captioning usua...  2019     47992019
# 11277  We consider classic clustering problems in ful...  2019     18272019
# 11278  When training complex neural networks, memory ...  2019     86932019
# 11279  Learning non-deterministic dynamics and intrin...  2019     23022019
#
#                                                full_text
# 0      A Graph Similarity for Deep Learning\nSeongmin...
# 1      An Unsupervised Information-Theoretic\nPercept...
# 2      Self-Supervised MultiModal Versatile Networks\...
# 3      Benchmarking Deep Inverse Models over time, an...
# 4      Off-Policy Evaluation and Learning\nfor Extern...
# ...                                                  ...
# 11275  Discrete Object Generation\n\nwith Reversible ...
# 11276  Adaptively Aligned Image Captioning via\n\nAda...
# 11277  Fully Dynamic Consistent Facility Location\n\n...
# 11278  Efﬁcient Rematerialization for Deep Networks\n...
# 11279  Flow-based Image-to-Image Translation\n\nwith ...
#
# [7938 rows x 6 columns]

# %% [markdown]
# ## Institution loading

# %%
institutions = pd.read_csv("./kaggle_archive/institutions.csv")

# check how many entries are deleted trough dropping missing data
print(f"deleted entries through missing data {institutions.shape[0]-institutions.dropna().shape[0]}")

# drop missing data
institutions = institutions.dropna()
# Out:
# deleted entries through missing data 0

# %%
institutions
# Out:
#     Unnamed: 0                       institutions               city state  \
# 0            0                stanford university           Stanford    CA
# 1            1                                mit          Cambridge    MA
# 2            2         carnegie mellon university         Pittsburgh    PA
# 3            3                        uc berkeley           Berkeley    CA
# 4            4                             google      Mountain View    CA
# ..         ...                                ...                ...   ...
# 95          95  the university of texas at austin             Austin    TX
# 96          96             university of virginia    Charlottesville    VA
# 97          97                           facebook         Menlo Park    CA
# 98          98                 rutgers university  Newark and Camden    NJ
# 99          99                      virginia tech         Blacksburg    VA
#
#    country
# 0       US
# 1       US
# 2       US
# 3       US
# 4       US
# ..     ...
# 95      US
# 96      US
# 97      US
# 98      US
# 99      US
#
# [100 rows x 5 columns]

# %% [markdown]
# # Preprocess Data
#
# ## Papers

# %%
# drop fulltext since not necessary and dataframe gets big through that
paper = paper.drop(['full_text'], axis=1)

# %% [markdown]
# ## Authors

# %%
## get unique paper_ids which are stored in authors
unique_paper_authors = authors["paper_index"].unique()

## get unique paper_ids which are stored in paper
### distortion because NaN removal
unique_paper_paper = paper["paper_index"].unique()

## have only values, which are in both arrays
unique_papers = np.fromiter((x for x in unique_paper_authors if x in unique_paper_paper),dtype='int')
print(f"All together, there are {unique_papers.shape[0]} unique papers")

## drop in autohr-dataframe all papers without information in the the paper-dataframe
drop_paper_indices = np.fromiter((x for x in unique_paper_authors if not(x in unique_paper_paper)),dtype='int')

authors = authors[~authors.paper_index.isin(drop_paper_indices)]
# authors["paper_index"].unique().shape[0] # controll
# Out:
# All together, there are 7918 unique papers

# %%
# get collection of all papers for each author

# get unique names
unique_authors = authors["name_in_database"].unique()
print(f"number of unique authors: {unique_authors.shape[0]}")
number_uniq_authors = unique_authors.shape[0]
# Out:
# number of unique authors: 13105

# %%
# create dictionary with unique authors as keys and paper_index as values
author_dict = {}
for uniq_authr in unique_authors:
    
    author_dict[uniq_authr] = list(authors.where(authors["name_in_database"] == 
                                                 uniq_authr).dropna()['paper_index'])

# author_dict

# %%
# save data into csv and json

# save into csv
f_csv = open("author_dict.csv", "w")
w = csv.writer(f_csv)
for key, val in author_dict.items():
    w.writerow([key, val])
f_csv.close()


# save into json
json = json.dumps(author_dict)
f = open("author_dict.json","w")
f.write(json)
f.close()

# %%
# create connection matrix between authors - based on number of common publications
## should be symmetrical TODO: more efficient way to save!
helper_matrix_conncetions = np.zeros((number_uniq_authors, number_uniq_authors))
connection_matrix = pd.DataFrame(helper_matrix_conncetions, columns=unique_authors, 
                                 index=unique_authors, dtype='int')
connection_matrix.head()
# Out:
#                        Sangnie Bhardwaj  Ian Fischer  Johannes Ballé  \
# Sangnie Bhardwaj                      0            0               0
# Ian Fischer                           0            0               0
# Johannes Ballé                        0            0               0
# Troy Chinen                           0            0               0
# Jean-Baptiste Alayrac                 0            0               0
#
#                        Troy Chinen  Jean-Baptiste Alayrac  Adrià Recasens  \
# Sangnie Bhardwaj                 0                      0               0
# Ian Fischer                      0                      0               0
# Johannes Ballé                   0                      0               0
# Troy Chinen                      0                      0               0
# Jean-Baptiste Alayrac            0                      0               0
#
#                        Relja Arandjelovic  Jason Ramapuram  Jeffrey De Fauw  \
# Sangnie Bhardwaj                        0                0                0
# Ian Fischer                             0                0                0
# Johannes Ballé                          0                0                0
# Troy Chinen                             0                0                0
# Jean-Baptiste Alayrac                   0                0                0
#
#                        Sander Dieleman  ...  Seth Lloyd  Ari Seff  Wenda Zhou  \
# Sangnie Bhardwaj                     0  ...           0         0           0
# Ian Fischer                          0  ...           0         0           0
# Johannes Ballé                       0  ...           0         0           0
# Troy Chinen                          0  ...           0         0           0
# Jean-Baptiste Alayrac                0  ...           0         0           0
#
#                        Farhan Damani  Abigail Doyle  Lun Huang  Yaxian Xia  \
# Sangnie Bhardwaj                   0              0          0           0
# Ian Fischer                        0              0          0           0
# Johannes Ballé                     0              0          0           0
# Troy Chinen                        0              0          0           0
# Jean-Baptiste Alayrac              0              0          0           0
#
#                        Niklas Oskar Hjuler  Erik Vee  Ruho Kondo
# Sangnie Bhardwaj                         0         0           0
# Ian Fischer                              0         0           0
# Johannes Ballé                           0         0           0
# Troy Chinen                              0         0           0
# Jean-Baptiste Alayrac                    0         0           0
#
# [5 rows x 13105 columns]

# %%
for current_author in unique_authors:
    for paper_list_index, paper_index in enumerate(author_dict[current_author]):
        a = authors[authors['paper_index'] == author_dict[current_author][paper_list_index]]['name_in_database']
        delete_own_name = a.index[a==current_author]
        a = a.drop(delete_own_name)
        for i in a:
            connection_matrix[current_author][i] += 1

# %%
connection_matrix
# Out:
#                        Sangnie Bhardwaj  Ian Fischer  Johannes Ballé  \
# Sangnie Bhardwaj                      0            1               1
# Ian Fischer                           1            0               1
# Johannes Ballé                        1            1               0
# Troy Chinen                           1            1               1
# Jean-Baptiste Alayrac                 0            0               0
# ...                                 ...          ...             ...
# Lun Huang                             0            0               0
# Yaxian Xia                            0            0               0
# Niklas Oskar Hjuler                   0            0               0
# Erik Vee                              0            0               0
# Ruho Kondo                            0            0               0
#
#                        Troy Chinen  Jean-Baptiste Alayrac  Adrià Recasens  \
# Sangnie Bhardwaj                 1                      0               0
# Ian Fischer                      1                      0               0
# Johannes Ballé                   1                      0               0
# Troy Chinen                      0                      0               0
# Jean-Baptiste Alayrac            0                      0               1
# ...                            ...                    ...             ...
# Lun Huang                        0                      0               0
# Yaxian Xia                       0                      0               0
# Niklas Oskar Hjuler              0                      0               0
# Erik Vee                         0                      0               0
# Ruho Kondo                       0                      0               0
#
#                        Relja Arandjelovic  Jason Ramapuram  Jeffrey De Fauw  \
# Sangnie Bhardwaj                        0                0                0
# Ian Fischer                             0                0                0
# Johannes Ballé                          0                0                0
# Troy Chinen                             0                0                0
# Jean-Baptiste Alayrac                   1                1                1
# ...                                   ...              ...              ...
# Lun Huang                               0                0                0
# Yaxian Xia                              0                0                0
# Niklas Oskar Hjuler                     0                0                0
# Erik Vee                                0                0                0
# Ruho Kondo                              0                0                0
#
#                        Sander Dieleman  ...  Seth Lloyd  Ari Seff  Wenda Zhou  \
# Sangnie Bhardwaj                     0  ...           0         0           0
# Ian Fischer                          0  ...           0         0           0
# Johannes Ballé                       0  ...           0         0           0
# Troy Chinen                          0  ...           0         0           0
# Jean-Baptiste Alayrac                1  ...           0         0           0
# ...                                ...  ...         ...       ...         ...
# Lun Huang                            0  ...           0         0           0
# Yaxian Xia                           0  ...           0         0           0
# Niklas Oskar Hjuler                  0  ...           0         0           0
# Erik Vee                             0  ...           0         0           0
# Ruho Kondo                           0  ...           0         0           0
#
#                        Farhan Damani  Abigail Doyle  Lun Huang  Yaxian Xia  \
# Sangnie Bhardwaj                   0              0          0           0
# Ian Fischer                        0              0          0           0
# Johannes Ballé                     0              0          0           0
# Troy Chinen                        0              0          0           0
# Jean-Baptiste Alayrac              0              0          0           0
# ...                              ...            ...        ...         ...
# Lun Huang                          0              0          0           1
# Yaxian Xia                         0              0          1           0
# Niklas Oskar Hjuler                0              0          0           0
# Erik Vee                           0              0          0           0
# Ruho Kondo                         0              0          0           0
#
#                        Niklas Oskar Hjuler  Erik Vee  Ruho Kondo
# Sangnie Bhardwaj                         0         0           0
# Ian Fischer                              0         0           0
# Johannes Ballé                           0         0           0
# Troy Chinen                              0         0           0
# Jean-Baptiste Alayrac                    0         0           0
# ...                                    ...       ...         ...
# Lun Huang                                0         0           0
# Yaxian Xia                               0         0           0
# Niklas Oskar Hjuler                      0         0           0
# Erik Vee                                 0         0           0
# Ruho Kondo                               0         0           0
#
# [13105 rows x 13105 columns]

# %%
# save connection matrix

## save as csv
connection_matrix.to_csv('connection_matrix.csv')

## save as json
result = connection_matrix.to_json('connection_matrix.json')
#parsed = json.loads(result)
#json.dumps(parsed, indent=4)
